# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,3,4])

# %%
plt.ylabel('Time Taken')
# Out:
# Text(0,0.5,'Time Taken')

# %%
plt.show()

# %%
plt.plot([1,2,3,4], [1,4,9,16], 'ro')

# %%
plt.plot([192, 256, 512, 1024, 2048], [44.17086, 71.11728, 470.755658, 9370.37895, 74833.668845])

# %%
plt.plot([2, 4, 8, 16, 32, 64, 128, 192, 256, 512, 1024, 2048], [0.063926, 0.133739, 0.531205, 1.075987, 1.14188, 7.780148, 9.859185, 44.17086, 71.11728, 470.755658, 9370.37895, 74833.668845])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1cac413256bb> in <module>()
# ----> 1 plt.plot([2, 4, 8, 16, 32, 64, 128, 192, 256, 512, 1024, 2048], [0.063926, 0.133739, 0.531205, 1.075987, 1.14188, 7.780148, 9.859185, 44.17086, 71.11728, 470.755658, 9370.37895, 74833.668845])
#
# NameError: name 'plt' is not defined

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([2, 4, 8, 16, 32, 64, 128, 192, 256, 512, 1024, 2048], [0.063926, 0.133739, 0.531205, 1.075987, 1.14188, 7.780148, 9.859185, 44.17086, 71.11728, 470.755658, 9370.37895, 74833.668845])

# %%
plt.plot([2, 4, 8, 16, 32, 64, 128, 192, 256, 512, 1024, 2048], [0.063926, 0.133739, 0.531205, 1.075987, 1.14188, 7.780148, 9.859185, 44.17086, 71.11728, 470.755658, 9370.37895, 74833.668845], 'ro')

# %%
plt.plot([2, 4, 8, 16, 32, 64, 128, 192, 256, 512, 1024, 2048], [0.063926, 0.133739, 0.531205, 1.075987, 1.14188, 7.780148, 9.859185, 44.17086, 71.11728, 470.755658, 9370.37895, 74833.668845], 'ro')
plt.ylabel('Time in milli seconds')
plt.xlabel('Size of Square matrix')
# Out:
# Text(0.5,0,'Size of Square matrix')

# %%
plt.plot([2, 4, 8, 16, 32, 64, 128, 192, 256, 512, 1024, 2048], [0.063926, 0.133739, 0.531205, 1.075987, 1.14188, 7.780148, 9.859185, 44.17086, 71.11728, 470.755658, 9370.37895])
plt.ylabel('Time in milli seconds')
plt.xlabel('Size of Square matrix')
# Out:
# Text(0.5,0,'Size of Square matrix')

# %%
# Standard Benchmarks for Runtime Analysis under concurrent programming.
# Final Graph
plt.plot([192, 256, 512, 1024, 2048], [64.8, 87.2, 235.2, 1168, 8882], 'r--')
plt.plot([192, 256, 512, 1024, 2048], [9.859185, 44.17086, 71.11728, 470.755658, 9370.37895])
plt.ylabel('Time in milli seconds')
plt.xlabel('Size of Square matrix')
plt.annotate('java', xy=(1024, 1168), xytext=(750, 3500),
            arrowprops=dict(facecolor='grey', shrink=0.05),
            )
plt.annotate('Go', xy=(1030, 470.755), xytext=(1250, 1000),
            arrowprops=dict(facecolor='grey', shrink=0.05),
            )
# Out:
# Text(1250,1000,'Go')
