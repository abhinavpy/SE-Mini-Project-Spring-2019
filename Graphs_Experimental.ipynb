# %%
# Standard Benchmarks for Runtime Analysis under concurrent programming.
# Final Graph
import matplotlib.pyplot as plt
plt.plot([192, 256, 512, 1024, 2048], [64.8, 87.2, 235.2, 1168, 8882], 'r--', label='Java')
plt.plot([192, 256, 512, 1024, 2048], [9.859185, 44.17086, 71.11728, 470.755658, 9370.37895], label='Golang')
plt.ylabel('Time in milli seconds')
plt.xlabel('Size of Square matrix')

plt.legend()
 
plt.savefig('concurrency_analysis.png')

# %%
# Binary Size Analysis Graph
import matplotlib.pyplot as plt
import numpy as np
objects = ('Java', 'Go')
y_pos = np.arange(len(objects))
performance = [8.1, 14.6]
plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('Binary Size')
plt.title('Programming language used for Binary Size')
plt.savefig('binary_size.png')
plt.show()

# %%
# User Time Analysis
import matplotlib.pyplot as plt
import numpy as np
objects = ('Java', 'Go')
y_pos = np.arange(len(objects))
performance = [1.90, 0.01]
plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('User time in seconds')
plt.title('Programming language for user time')
plt.savefig('user_time.png')
plt.show()

# %%
# System Time Analysis
import matplotlib.pyplot as plt
import numpy as np
objects = ('Java', 'Go')
y_pos = np.arange(len(objects))
performance = [0.08, 0.00]
plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('System time in seconds')
plt.title('Programming language for system time')
plt.savefig('system_time.png')
plt.show()

# %%
# Percent of CPU this job got analysis Analysis
import matplotlib.pyplot as plt
import numpy as np
objects = ('Java', 'Go')
y_pos = np.arange(len(objects))
performance = [209, 119]
plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('Percentage of CPU this job got Analysis')
plt.title('Programming language')
plt.savefig('percent_cpu_time.png')
plt.show()

# %%
# Compilation time (Elapsed Time) Analysis
import matplotlib.pyplot as plt
import numpy as np
objects = ('Java', 'Go')
y_pos = np.arange(len(objects))
performance = [94, 2]
plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('Compilation Time "Elapsed time"')
plt.title('Programming language')
plt.savefig('compilaiton_time_elapsed_time.png')
plt.show()

# %%
# Maximum Resident Set Size Analysis
import matplotlib.pyplot as plt
import numpy as np
objects = ('Java', 'Go')
y_pos = np.arange(len(objects))
performance = [58568, 10652]
plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('Maximum resident set size in kbytes')
plt.title('Programming language')
plt.savefig('maximum_resident_set_size.png')
plt.show()

# %%
# Minor (Reclaiming a page) page faults Analysis
import matplotlib.pyplot as plt
import numpy as np
objects = ('Java', 'Go')
y_pos = np.arange(len(objects))
performance = [787, 11383]
plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('Minor (Reclaiming a page) page faults')
plt.title('Programming language')
plt.savefig('minor_page_faults.png')
plt.show()

# %%
# Voluntary Context Switches Analysis
import matplotlib.pyplot as plt
import numpy as np
objects = ('Java', 'Go')
y_pos = np.arange(len(objects))
performance = [1385, 711]
plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('Voluntary Context Switches')
plt.title('Programming language')
plt.savefig('voluntary_context_switches.png')
plt.show()

# %%
# Involuntary Context Switches Analysis
import matplotlib.pyplot as plt
import numpy as np
objects = ('Java', 'Go')
y_pos = np.arange(len(objects))
performance = [164, 27]
plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('Involuntary Context Switches')
plt.title('Programming language')
plt.savefig('involuntary_context_switches.png')
plt.show()

# %%
# page rank algorithm 7x7
# Standard Benchmarks for Runtime Analysis under concurrent programming for page rank algorithm 7x7.
# Final Graph
import matplotlib.pyplot as plt
plt.plot([0.01, 0.02, 0.04, 0.06, 0.08, 0.1], [45, 38, 33, 27, 23, 24], 'r--', label='Java')
plt.plot([0.01, 0.02, 0.04, 0.06, 0.08, 0.1], [45.55, 39.72, 22.708, 21.03, 20.83, 17.985], label='Golang')
plt.ylabel('Time in microseconds')
plt.xlabel('Value of epsilon for a 7x7 matrix containing pages')
# plt.annotate('Java', xy=(0.04, 33), xytext=(0.05, 32),
#             arrowprops=dict(facecolor='grey', shrink=0.05),
#             )
# plt.annotate('Go', xy=(0.04, 23),xytext=(0.05, 20),
#             arrowprops=dict(facecolor='grey', shrink=0.05),
#             )
plt.legend()
plt.savefig('page_rank7x7_analysis.png')
plt.show()

# %%
# Standard Benchmarks for Runtime Analysis under concurrent programming for page rank algorithm 7x7.
# Final Graph
import matplotlib.pyplot as plt
plt.plot([0.00001, 0.0001, 0.0005, 0.001, 0.005, 0.05, 0.1], [56,37,35,33,30,19,14], 'r--', label='Java')
plt.plot([0.00001, 0.0001, 0.0005, 0.001, 0.005, 0.05, 0.1], [43.048, 36.97, 36.072, 31.661, 23.98, 17.102, 12.113], label='Golang')
plt.ylabel('Time in micro seconds')
plt.xlabel('Value of epsilon for a 3x3 matrix containing pages')
# plt.annotate('Java', xy=(0.04, 21), xytext=(0.05, 32),
#             arrowprops=dict(facecolor='grey', shrink=0.05),
#             )
# plt.annotate('Go', xy=(0.04, 18.5), xytext=(0.05, 20),
#             arrowprops=dict(facecolor='grey', shrink=0.05),
#             )
plt.legend()
plt.savefig('page_rank3x3_analysis.png')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
 
# data to plot
n_groups = 2
means_frank = (14.6, 27.1)
means_guido = (8.1, 3.1)
 
# create plot
fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.35
opacity = 0.8
 
rects1 = plt.bar(index, means_frank, bar_width,
alpha=opacity,
color='b',
label='Golang')
 
rects2 = plt.bar(index + bar_width, means_guido, bar_width,
alpha=opacity,
color='g',
label='Java')
 
plt.xlabel('Type of Algorithm used')
plt.ylabel('Size in kilobytes')
plt.title('Binary Size Analysis')
plt.xticks(index + bar_width, ('Matrix Multiplication', 'Page Rank'))
plt.legend()
 
plt.tight_layout()
plt.savefig('binary_analysis_both_algos.png')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
 
# data to plot
n_groups = 2
means_frank = (0.02, 0.01)
means_guido = (0.94, 3.14)
 
# create plot
fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.35
opacity = 0.8
 
rects1 = plt.bar(index, means_frank, bar_width,
alpha=opacity,
color='b',
label='Golang')
 
rects2 = plt.bar(index + bar_width, means_guido, bar_width,
alpha=opacity,
color='g',
label='Java')
 
plt.xlabel('Type of Algorithm')
plt.ylabel('Time in seconds')
plt.title('Compile Time Analysis')
plt.xticks(index + bar_width, ('Matrix Multiplication', 'Page Rank'))
plt.legend()
 
plt.tight_layout()
plt.savefig('compile_time_analysis_both_algos.png')
plt.show()
